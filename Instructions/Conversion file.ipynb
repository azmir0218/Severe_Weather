# %%
import pandas as pd

# %%
df=pd.read_csv('StarterCode/data1.csv')
df.head()
# Out:
#     Latitude  Longitude State  \
# 0  32.806671  -86.79113    AL
# 1  32.806671  -86.79113    AL
# 2  32.806671  -86.79113    AL
# 3  32.806671  -86.79113    AL
# 4  32.806671  -86.79113    AL
#
#                                                 Name      Disaster  \
# 0  Southern Tornado Outbreak and Western Storms (...  Severe Storm
# 1    Central/Southeast Tornado Outbreak (March 2017)  Severe Storm
# 2                      Southeast Freeze (March 2017)        Freeze
# 3        South/Southeast Severe Weather (March 2017)  Severe Storm
# 4  Missouri and Arkansas Flooding and Central Sev...      Flooding
#
#    Year_start  Year_end  Total_dam  Deaths
# 0        2017      2017     1259.7      24
# 1        2017      2017     2058.7       6
# 2        2017      2017     1140.0       0
# 3        2017      2017     3072.3       0
# 4        2017      2017     1891.3      20

# %%
# data_html=df.set_index("City_ID")

# %%
df.to_html("StarterCode/data1.html")

# %%
df_1=pd.read_csv('StarterCode/data2.csv')
df_1.head()
# Out:
#     Latitude  Longitude State  \
# 0  32.806671 -86.791130    AL
# 1  32.806671 -86.791130    AL
# 2  32.806671 -86.791130    AL
# 3  32.806671 -86.791130    AL
# 4  34.969704 -92.373123    AR
#
#                                                 Name          Disaster  \
# 0  Southeastern Tornadoes and Severe Weather (Mar...      Severe Storm
# 1  Southern and Eastern Tornadoes and Severe Weat...      Severe Storm
# 2  Central and Eastern Tornadoes and Severe Weath...      Severe Storm
# 3                   Hurricane Michael (October 2018)  Tropical Cyclone
# 4  Southern and Eastern Tornadoes and Severe Weat...      Severe Storm
#
#    Year_start  Year_end  Total_dam  Deaths
# 0        2018      2018     1626.2       0
# 1        2018      2018     1463.2       3
# 2        2018      2018     1743.5       0
# 3        2018      2018    27472.5      49
# 4        2018      2018     1463.2       3

# %%
df_1.to_html("StarterCode/data2.html")

# %%
df_2=pd.read_csv('StarterCode/data3.csv')
df_2.head()
# Out:
#     Latitude   Longitude State  \
# 0  32.806671  -86.791130    AL
# 1  32.806671  -86.791130    AL
# 2  32.806671  -86.791130    AL
# 3  61.370716 -152.404419    AK
# 4  34.969704  -92.373123    AR
#
#                                                 Name      Disaster  \
# 0  Southeast, Ohio Valley and Northeast Severe We...  Severe Storm
# 1  Southern and Eastern Tornadoes and Severe Weat...  Severe Storm
# 2      South and Southeast Severe Weather (May 2019)  Severe Storm
# 3  California and Alaska Wildfires (Summer-Fall 2...      Wildfire
# 4      South and Southeast Severe Weather (May 2019)  Severe Storm
#
#    Year_start  Year_end  Total_dam  Deaths
# 0        2019      2019     1361.1       2
# 1        2019      2019     1364.7       7
# 2        2019      2019     1650.5       0
# 3        2019      2019     4905.0       3
# 4        2019      2019     1650.5       0

# %%
df_2.to_html("StarterCode/data3.html")

# %%
df_3=pd.read_csv('StarterCode/data4.csv')
df_3.head()
# Out:
#     Latitude  Longitude State  \
# 0  32.806671  -86.79113    AL
# 1  32.806671  -86.79113    AL
# 2  32.806671  -86.79113    AL
# 3  32.806671  -86.79113    AL
# 4  32.806671  -86.79113    AL
#
#                                                 Name      Disaster  \
# 0  Southeast Tornadoes and Northern Storms and Fl...  Severe Storm
# 1  South, East and Northeast Severe Weather (Febr...  Severe Storm
# 2  Tennessee Tornadoes and Southeast Severe Weath...  Severe Storm
# 3  Southeast and Eastern Tornado Outbreak (April ...  Severe Storm
# 4               Southern Severe Weather (April 2020)  Severe Storm
#
#    Year_start  Year_end  Total_dam  Deaths
# 0        2020      2020     1240.9      10
# 1        2020      2020     1344.3       3
# 2        2020      2020     2522.8      25
# 3        2020      2020     3719.3      35
# 4        2020      2020     1458.0       3

# %%
df_3.to_html("StarterCode/data4.html")

# %%
df_4=pd.read_csv('StarterCode/data5.csv')
df_4.head()
# Out:
#     Latitude  Longitude State  \
# 0  32.806671  -86.79113    AL
# 1  32.806671  -86.79113    AL
# 2  32.806671  -86.79113    AL
# 3  32.806671  -86.79113    AL
# 4  32.806671  -86.79113    AL
#
#                                                 Name          Disaster  \
# 0  Southeast Tornadoes and Severe Weather (March ...      Severe Storm
# 1                Eastern Severe Weather (March 2021)      Severe Storm
# 2  Southern Tornadoes and Southeast Severe Weathe...      Severe Storm
# 3                  Tropical Storm Fred (August 2021)  Tropical Cyclone
# 4                        Hurricane Ida (August 2021)  Tropical Cyclone
#
#    Year_start  Year_end  Total_dam  Deaths
# 0        2021      2021     1761.1       6
# 1        2021      2021     1413.6       8
# 2        2021      2021     1302.2       4
# 3        2021      2021     1302.5       7
# 4        2021      2021    75043.5      96

# %%
df_4.to_html("StarterCode/data5.html")

# %%
df_5=pd.read_csv('StarterCode/AllWeatherEvents.csv')
df_5.head()
# Out:
# /Users/azmirsuljic/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (2,3,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Latitude  Longitude State  \
# 0  32.806671  -86.79113    AL
# 1  32.806671  -86.79113    AL
# 2  32.806671  -86.79113    AL
# 3  32.806671  -86.79113    AL
# 4  32.806671  -86.79113    AL
#
#                                                 Name      Disaster  \
# 0  Southern Tornado Outbreak and Western Storms (...  Severe Storm
# 1    Central/Southeast Tornado Outbreak (March 2017)  Severe Storm
# 2                      Southeast Freeze (March 2017)        Freeze
# 3        South/Southeast Severe Weather (March 2017)  Severe Storm
# 4  Missouri and Arkansas Flooding and Central Sev...      Flooding
#
#    Year_start  Year_end  Total_dam  Deaths
# 0      2017.0    2017.0     1259.7    24.0
# ...

# %%
df_5.to_html("StarterCode/data6.html")
